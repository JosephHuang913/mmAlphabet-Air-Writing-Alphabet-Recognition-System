# %%
import numpy as np

# %% [markdown]
# ### V1，取平方計算Power，並取平均的向量組成Spectrogram

# %% [markdown]
# #### V1 Cross validation, mixed dataset

# %%
V1_cross_val_mixed_1234 = [0.9536, 0.8962, 0.9269, 0.9561, 0.9291, 0.9061, 0.9458, 0.9157, 0.9158, 0.9066, 0.9154, 0.9198, 0.9383, 0.9447, 0.884, 0.9293, 0.8764, 0.8194, 0.9048, 0.9311]

# %%
V1_cross_val_mixed_5678 = [0.8662, 0.8978, 0.8927, 0.8859, 0.9484, 0.9193, 0.9232, 0.9338, 0.9118, 0.8211, 0.8691, 0.9366, 0.8987, 0.9112, 0.8956, 0.9157, 0.8792, 0.8981, 0.9138, 0.9415]

# %%
V1_cross_val_mixed_123 = [0.8172, 0.9162, 0.8804, 0.9328, 0.9041, 0.9441, 0.9484, 0.9309, 0.9065, 0.9394, 0.8783, 0.929, 0.9015, 0.9204, 0.9037, 0.8951, 0.8895, 0.9232, 0.8495, 0.9138]

# %%
V1_cross_val_mixed_456 = [0.9392, 0.9322, 0.9436, 0.9331, 0.9388, 0.8848, 0.8991, 0.9227, 0.9491, 0.8668, 0.9481, 0.8645, 0.9363, 0.8683, 0.9506, 0.897, 0.8833, 0.9368, 0.9059, 0.8816]

# %%
V1_cross_val_mixed_7890 = [0.9221, 0.9319, 0.9385, 0.9474, 0.8678, 0.877, 0.8527, 0.9161, 0.9401, 0.9506, 0.9223, 0.9313, 0.8936, 0.8454, 0.838, 0.8842, 0.9022, 0.947, 0.939, 0.8929]

# %%
V1_cross_val_mixed = V1_cross_val_mixed_1234 + V1_cross_val_mixed_5678 + V1_cross_val_mixed_123 + V1_cross_val_mixed_456 + V1_cross_val_mixed_7890

# %%
V1_cross_val_mixed_max = np.max(V1_cross_val_mixed)
V1_cross_val_mixed_max
# Out:
# 0.9561

# %%
V1_cross_val_mixed_avg = np.mean(V1_cross_val_mixed)
V1_cross_val_mixed_avg
# Out:
# 0.9092069999999999

# %% [markdown]
# #### V1 LOO Cross validation, mixed dataset

# %%
V1_LOO_mixed_emily = [0.7733, 0.7432, 0.7036, 0.6636, 0.8116, 0.7585, 0.6995, 0.7793, 0.7043, 0.7641, 0.7275, 0.7212, 0.7534, 0.7028, 0.7308, 0.7714, 0.7045, 0.7542, 0.7372, 0.6899]

# %%
V1_LOO_mixed_grace = [0.5983, 0.5796, 0.5375, 0.4652, 0.6122, 0.5881, 0.546, 0.5261, 0.5522, 0.5137, 0.6132, 0.5384, 0.5972, 0.5692, 0.5386, 0.5672, 0.5813, 0.5663, 0.6316, 0.5763]

# %%
V1_LOO_mixed_joseph = [0.7849, 0.7317, 0.8145, 0.8114, 0.7783, 0.823, 0.7513, 0.8166, 0.7845, 0.7886, 0.8046, 0.8348, 0.7932, 0.7652, 0.7227, 0.7777, 0.7928, 0.7416, 0.7487, 0.7857]

# %%
V1_LOO_mixed_kenny = [0.6733, 0.6689, 0.5918, 0.6374, 0.5461, 0.7231, 0.6654, 0.6534, 0.7171, 0.6905, 0.6636, 0.7264, 0.6297, 0.6828, 0.6928, 0.6044, 0.6793, 0.6231, 0.7063, 0.6559]

# %%
V1_LOO_mixed_paul = [0.758, 0.6797, 0.7445, 0.6658, 0.6504, 0.6819, 0.7617, 0.7659, 0.7393, 0.6902, 0.7627, 0.7103, 0.6726, 0.7016, 0.7918, 0.6807, 0.7033, 0.7744, 0.7627, 0.6401]

# %%
V1_LOO_mixed_peggy = [0.6119, 0.6786, 0.6223, 0.6225, 0.6268, 0.6109, 0.6007, 0.597, 0.633, 0.6494, 0.6438, 0.5918, 0.6544, 0.632, 0.5446, 0.5905, 0.5273, 0.5953, 0.6049, 0.6479]

# %%
V1_LOO_mixed_vincent = [0.9258, 0.9337, 0.9463, 0.9314, 0.9324, 0.9018, 0.9436, 0.9182, 0.9074, 0.9447, 0.9314, 0.9221, 0.9233, 0.924, 0.9681, 0.8954, 0.8659, 0.8914, 0.9215, 0.8355]

# %%
V1_LOO_mixed_max_avg = (np.max(V1_LOO_mixed_emily) + np.max(V1_LOO_mixed_grace) + np.max(V1_LOO_mixed_joseph) 
                        + np.max(V1_LOO_mixed_kenny) + np.max(V1_LOO_mixed_paul) + np.max(V1_LOO_mixed_peggy)
                        + np.max(V1_LOO_mixed_vincent))/7
V1_LOO_mixed_max_avg
# Out:
# 0.7775571428571428

# %%
V1_LOO_mixed_avg = np.mean(V1_LOO_mixed_emily+V1_LOO_mixed_grace+V1_LOO_mixed_joseph
                           +V1_LOO_mixed_kenny+V1_LOO_mixed_paul+V1_LOO_mixed_peggy+V1_LOO_mixed_vincent)
V1_LOO_mixed_avg
# Out:
# 0.7133021428571429

# %% [markdown]
# #### V1 Cross validation, Free Style dataset

# %%
V1_cross_val_free_1234 = [0.9049, 0.9115, 0.8978, 0.8338, 0.9137, 0.8736, 0.8992, 0.8497, 0.8918, 0.914, 0.8714, 0.928, 0.9011, 0.9036, 0.819, 0.8646, 0.8841, 0.8929, 0.7846, 0.8162]

# %%
V1_cross_val_free_5678 = [0.8945, 0.8327, 0.8761, 0.8508, 0.8538, 0.8437, 0.7931, 0.9038, 0.8854, 0.8563, 0.8885, 0.8547, 0.9093, 0.8758, 0.8481, 0.9077, 0.7989, 0.8555, 0.8376, 0.8937]

# %%
V1_cross_val_free_123 = [0.833, 0.856, 0.9104, 0.7382, 0.7712, 0.922, 0.8527, 0.9209, 0.8797, 0.9332, 0.8937, 0.8629, 0.8871, 0.8937, 0.9173, 0.8607, 0.8242, 0.8357, 0.9288, 0.8374]

# %%
V1_cross_val_free_456 = [0.917, 0.8659, 0.8662, 0.8654, 0.8591, 0.8896, 0.8593, 0.8385, 0.8794, 0.8986, 0.8096, 0.9247, 0.856, 0.8393, 0.8904, 0.7456, 0.7901, 0.8253, 0.9173, 0.8728]

# %%
V1_cross_val_free_7890 = [0.8684, 0.8596, 0.8805, 0.9184, 0.9297, 0.8753, 0.8992, 0.869, 0.8379, 0.9223, 0.825, 0.8734, 0.8786, 0.8626, 0.8115, 0.8896, 0.8099, 0.7868, 0.8541, 0.8102]

# %%
V1_cross_val_free = V1_cross_val_free_1234 + V1_cross_val_free_5678 + V1_cross_val_free_123 + V1_cross_val_free_456 + V1_cross_val_free_7890

# %%
V1_cross_val_free_max = np.max(V1_cross_val_free)
V1_cross_val_free_max
# Out:
# 0.9332

# %%
V1_cross_val_free_avg = np.mean(V1_cross_val_free)
V1_cross_val_free_avg
# Out:
# 0.866464

# %% [markdown]
# #### V1 LOO Cross validation, Free Style dataset

# %%
V1_LOO_free_emily = [0.589, 0.4996, 0.6131, 0.6752, 0.6142, 0.519, 0.648, 0.6068, 0.6232, 0.6235, 0.6216, 0.587, 0.5389, 0.6558, 0.5377, 0.5455, 0.6488, 0.657, 0.5082, 0.5416]

# %%
V1_LOO_free_grace = [0.2517, 0.3427, 0.3318, 0.2762, 0.3104, 0.2964, 0.3003, 0.2949, 0.3306, 0.2945, 0.3294, 0.2615, 0.3427, 0.249, 0.2176, 0.3376, 0.2762, 0.3349, 0.3007, 0.3368]

# %%
V1_LOO_free_joseph = [0.6503, 0.6018, 0.5602, 0.5307, 0.5070, 0.4868, 0.4786, 0.4402, 0.6659, 0.4507, 0.5824, 0.6146, 0.5486, 0.5711, 0.5765, 0.6111, 0.6298, 0.6368, 0.6235, 0.4957]

# %%
V1_LOO_free_kenny = [0.5159, 0.5474, 0.5385, 0.5155, 0.4134, 0.5536, 0.4922, 0.5152, 0.3617, 0.4984, 0.4821, 0.4918, 0.5245, 0.4856, 0.5381, 0.5113, 0.5155, 0.5587, 0.4184, 0.5105]

# %%
V1_LOO_free_paul = [0.6084, 0.5253, 0.6068, 0.6111, 0.5995, 0.5536, 0.6193, 0.6185, 0.5808, 0.5785, 0.5206, 0.6162, 0.636, 0.6154, 0.5225, 0.6204, 0.5284, 0.6702, 0.603, 0.5672]

# %%
V1_LOO_free_peggy = [0.4021, 0.3873, 0.4371, 0.4538, 0.3862, 0.4211, 0.3535, 0.3963, 0.4448, 0.4507, 0.4604, 0.3632, 0.427, 0.3819, 0.4316, 0.46, 0.4239, 0.2949, 0.4048, 0.4308]

# %%
V1_LOO_free_vincent = [0.8333, 0.7681, 0.7591, 0.8465, 0.8077, 0.7502, 0.8897, 0.8361, 0.8357, 0.8166, 0.8512, 0.7086, 0.7642, 0.798, 0.8644, 0.8454, 0.8594, 0.8411, 0.8081, 0.826]

# %%
V1_LOO_free_max_avg = (np.max(V1_LOO_free_emily) + np.max(V1_LOO_free_grace) + np.max(V1_LOO_free_joseph) 
                       + np.max(V1_LOO_free_kenny) + np.max(V1_LOO_free_paul) + np.max(V1_LOO_free_peggy)
                       + np.max(V1_LOO_free_vincent))/7
V1_LOO_free_max_avg
# Out:
# 0.6089714285714286

# %%
V1_LOO_free_avg = np.mean(V1_LOO_free_emily+V1_LOO_free_grace+V1_LOO_free_joseph
                          +V1_LOO_free_kenny+V1_LOO_free_paul+V1_LOO_free_peggy+V1_LOO_free_vincent)
V1_LOO_free_avg
# Out:
# 0.5388764285714286

# %% [markdown]
# #### V1 Cross validation, Stipulated dataset

# %%
V1_cross_val_stipulated_1234 = [0.9303, 0.8907, 0.9075, 0.8871, 0.9128, 0.8891, 0.9105, 0.9033, 0.9094, 0.925, 0.9012, 0.8918, 0.8451, 0.925, 0.9083, 0.8556, 0.9297, 0.8907, 0.9311, 0.8512]

# %%
V1_cross_val_stipulated_5678 = [0.9215, 0.8679, 0.899, 0.9239, 0.9217, 0.9248, 0.9281, 0.9003, 0.9069, 0.8413, 0.9195, 0.9338, 0.9127, 0.9283, 0.9212, 0.9143, 0.8556, 0.8828, 0.8699, 0.953]

# %%
V1_cross_val_stipulated_123 = [0.8918, 0.8828, 0.8726, 0.8841, 0.8674, 0.8946, 0.8948, 0.869, 0.8424, 0.9347, 0.8635, 0.9322, 0.911, 0.8954, 0.9198, 0.922, 0.8375, 0.8572, 0.7306, 0.9242]

# %%
V1_cross_val_stipulated_456 = [0.8968, 0.9248, 0.9198, 0.9434, 0.8682, 0.8635, 0.8803, 0.8638, 0.9102, 0.8613, 0.905, 0.8959, 0.8863, 0.958, 0.9393, 0.9209, 0.9121, 0.9042, 0.8959, 0.8863]

# %%
V1_cross_val_stipulated_7890 = [0.9031, 0.8778, 0.9017, 0.8795, 0.9204, 0.9138, 0.8589, 0.9058, 0.9091, 0.927, 0.8745, 0.8528, 0.8965, 0.9017, 0.9168, 0.9289, 0.9174, 0.9165, 0.9185, 0.8748]

# %%
V1_cross_val_stipulated = V1_cross_val_stipulated_1234 + V1_cross_val_stipulated_5678 + V1_cross_val_stipulated_123 + V1_cross_val_stipulated_456 + V1_cross_val_stipulated_7890

# %%
V1_cross_val_stipulated_max = np.max(V1_cross_val_stipulated)
V1_cross_val_stipulated_max
# Out:
# 0.958

# %%
V1_cross_val_stipulated_avg = np.mean(V1_cross_val_stipulated)
V1_cross_val_stipulated_avg
# Out:
# 0.8978099999999998

# %% [markdown]
# #### V1 LOO Cross validation, Stipulated dataset

# %%
V1_LOO_stipulated_emily = [0.6878, 0.6435, 0.6777, 0.7658, 0.7421, 0.7623, 0.7604, 0.7565, 0.7627, 0.6862, 0.6113, 0.7464, 0.727, 0.7095, 0.7903, 0.7417, 0.7577, 0.7557, 0.701, 0.7324]

# %%
V1_LOO_stipulated_grace = [0.7484, 0.6316, 0.6627, 0.5547, 0.6223, 0.7073, 0.7034, 0.7193, 0.7547, 0.6564, 0.7314, 0.7655, 0.7104, 0.7054, 0.729, 0.7057, 0.5792, 0.743, 0.7764, 0.6902]

# %%
V1_LOO_stipulated_joseph = [0.8318, 0.8178, 0.8166, 0.777, 0.7945, 0.8139, 0.7409, 0.8757, 0.8256, 0.8644, 0.8462, 0.7603, 0.8221, 0.8372, 0.843, 0.8838, 0.8131, 0.7906, 0.8267, 0.8271]

# %%
V1_LOO_stipulated_kenny = [0.7231, 0.6813, 0.6983, 0.6844, 0.6964, 0.6976, 0.6933, 0.6689, 0.6766, 0.7546, 0.6747, 0.7158, 0.6619, 0.7181, 0.6483, 0.7348, 0.6619, 0.6832, 0.7022, 0.6413]

# %%
V1_LOO_stipulated_paul = [0.7576, 0.7549, 0.7444, 0.6869, 0.7075, 0.7587, 0.7541, 0.7416, 0.7708, 0.7506, 0.8003, 0.7638, 0.6962, 0.7304, 0.695, 0.6636, 0.7665, 0.7183, 0.7653, 0.7246]

# %%
V1_LOO_stipulated_peggy = [0.7129, 0.6026, 0.6861, 0.7145, 0.711, 0.6605, 0.7059, 0.6527, 0.6301, 0.7067, 0.6601, 0.6888, 0.6706, 0.608, 0.6523, 0.6554, 0.6383, 0.7129, 0.6818, 0.6667]

# %%
V1_LOO_stipulated_vincent = [0.9037, 0.8648, 0.8834, 0.8811, 0.911, 0.8283, 0.8667, 0.7964, 0.8702, 0.8232, 0.8768, 0.9075, 0.8788, 0.8811, 0.8271, 0.8768, 0.8236, 0.8761, 0.7214, 0.8508]

# %%
V1_LOO_stipulated_max_avg = (np.max(V1_LOO_stipulated_emily) + np.max(V1_LOO_stipulated_grace) 
                             + np.max(V1_LOO_stipulated_joseph) + np.max(V1_LOO_stipulated_kenny) 
                             + np.max(V1_LOO_stipulated_paul) + np.max(V1_LOO_stipulated_peggy)
                             + np.max(V1_LOO_stipulated_vincent))/7
V1_LOO_stipulated_max_avg
# Out:
# 0.8044142857142857

# %%
V1_LOO_stipulated_avg = np.mean(V1_LOO_stipulated_emily+V1_LOO_stipulated_grace+V1_LOO_stipulated_joseph
                                +V1_LOO_stipulated_kenny+V1_LOO_stipulated_paul+V1_LOO_stipulated_peggy
                                +V1_LOO_stipulated_vincent)
V1_LOO_stipulated_avg
# Out:
# 0.7425557142857143

# %% [markdown]
# ### V2，取絕對值計算Amplitude，並取平均的向量組成Spectrogram

# %% [markdown]
# #### V2 Cross validation, mixed dataset

# %%
V2_cross_val_mixed_1234 = [0.9662, 0.951, 0.9695, 0.9636, 0.9654, 0.9717, 0.9691, 0.9676, 0.9389, 0.9621, 0.9352, 0.965, 0.9525, 0.9558, 0.9631, 0.968, 0.9558, 0.9528, 0.9636, 0.9728]

# %%
V2_cross_val_mixed_5678 = [0.9507, 0.9263, 0.95, 0.9596, 0.9523, 0.9562, 0.9633, 0.9342, 0.9315, 0.9639, 0.9396, 0.912, 0.9587, 0.9609, 0.9705, 0.9488, 0.9631, 0.9603, 0.9563, 0.964]

# %%
V2_cross_val_mixed_123 = [0.9633, 0.9431, 0.9425, 0.9592, 0.9639, 0.9381, 0.9447, 0.9502, 0.9547, 0.9374, 0.9653, 0.968, 0.9478, 0.9637, 0.9447, 0.9464, 0.9558, 0.9539, 0.9673, 0.9348]

# %%
V2_cross_val_mixed_456 = [0.9589, 0.9653, 0.9414, 0.9664, 0.961, 0.9415, 0.9591, 0.9705, 0.9611, 0.9289, 0.9591, 0.9631, 0.9603, 0.9659, 0.9632, 0.9687, 0.9569, 0.9561, 0.9687, 0.9605]

# %%
V2_cross_val_mixed_7890 = [0.9511, 0.9657, 0.9543, 0.9555, 0.9534, 0.9552, 0.9382, 0.9529, 0.9657, 0.9556, 0.9436, 0.9658, 0.9548, 0.9405, 0.9488, 0.9304, 0.9558, 0.9489, 0.96, 0.9537]

# %%
V2_cross_val_mixed = V2_cross_val_mixed_1234 + V2_cross_val_mixed_5678 + V2_cross_val_mixed_123 + V2_cross_val_mixed_456 + V2_cross_val_mixed_7890

# %%
V2_cross_val_mixed_max = np.max(V2_cross_val_mixed)
V2_cross_val_mixed_max
# Out:
# 0.9728

# %%
V2_cross_val_mixed_avg = np.mean(V2_cross_val_mixed)
V2_cross_val_mixed_avg
# Out:
# 0.9550319999999999

# %% [markdown]
# #### V2 LOO Cross validation, mixed dataset

# %%
V2_LOO_mixed_emily = [0.8106, 0.8093, 0.75, 0.8415, 0.833, 0.7813, 0.7807, 0.8278, 0.7757, 0.8286, 0.7942, 0.7594, 0.8019, 0.8139, 0.8199, 0.8421, 0.8377, 0.8305, 0.8479, 0.8014]

# %%
V2_LOO_mixed_grace = [0.6474, 0.6221, 0.648, 0.6179, 0.6459, 0.6231, 0.6443, 0.5833, 0.5914, 0.618, 0.556, 0.6609, 0.6354, 0.6385, 0.6383, 0.5918, 0.6443, 0.6024, 0.6049, 0.6374]

# %%
V2_LOO_mixed_joseph = [0.8118, 0.8125, 0.885, 0.7911, 0.8235, 0.827, 0.8579, 0.7905, 0.8574, 0.8773, 0.7773, 0.8133, 0.8394, 0.8606, 0.7708, 0.8419, 0.81, 0.8348, 0.8494, 0.804]

# %%
V2_LOO_mixed_kenny = [0.6774, 0.7438, 0.7206, 0.7355, 0.7171, 0.7517, 0.7397, 0.7158, 0.7366, 0.726, 0.7289, 0.7822, 0.7291, 0.7432, 0.7386, 0.7509, 0.749, 0.7167, 0.7276, 0.7534]

# %%
V2_LOO_mixed_paul = [0.8247, 0.7947, 0.7893, 0.7872, 0.7957, 0.7518, 0.7234, 0.7719, 0.8187, 0.8038, 0.7917, 0.7998, 0.8216, 0.8185, 0.7853, 0.7965, 0.8027, 0.8063, 0.7992, 0.8021]

# %%
V2_LOO_mixed_peggy = [0.6904, 0.6927, 0.7211, 0.6915, 0.6359, 0.6482, 0.6301, 0.6519, 0.6374, 0.656, 0.6954, 0.6301, 0.6939, 0.6728, 0.6788, 0.7344, 0.6838, 0.7, 0.7099, 0.6736]

# %%
V2_LOO_mixed_vincent = [0.9476, 0.9554, 0.9751, 0.9525, 0.9457, 0.9511, 0.9544, 0.9298, 0.9449, 0.9393, 0.9515, 0.9461, 0.9648, 0.9639, 0.9432, 0.9387, 0.9563, 0.9499, 0.9426, 0.9409]

# %%
V2_LOO_mixed_max_avg = (np.max(V2_LOO_mixed_emily) + np.max(V2_LOO_mixed_grace) + np.max(V2_LOO_mixed_joseph) 
                        + np.max(V2_LOO_mixed_kenny) + np.max(V2_LOO_mixed_paul) + np.max(V2_LOO_mixed_peggy)
                        + np.max(V2_LOO_mixed_vincent))/7
V2_LOO_mixed_max_avg
# Out:
# 0.8157428571428572

# %%
V2_LOO_mixed_avg = np.mean(V2_LOO_mixed_emily+V2_LOO_mixed_grace+V2_LOO_mixed_joseph+V2_LOO_mixed_kenny
                           +V2_LOO_mixed_paul+V2_LOO_mixed_peggy+V2_LOO_mixed_vincent)
V2_LOO_mixed_avg
# Out:
# 0.7733178571428572

# %% [markdown]
# #### V2 Cross validation, Free Style dataset

# %%
V2_cross_val_free_1234 = [0.9442, 0.9338, 0.9577, 0.9591, 0.9396, 0.931, 0.9527, 0.953, 0.9371, 0.9322, 0.9593, 0.9376, 0.9478, 0.9429, 0.9434, 0.9255, 0.9451, 0.9401, 0.9481, 0.936]

# %%
V2_cross_val_free_5678 = [0.9497, 0.9577, 0.9588, 0.9349, 0.9475, 0.9467, 0.9593, 0.9541, 0.9525, 0.9343, 0.9168, 0.9484, 0.9459, 0.9563, 0.9602, 0.9316, 0.944, 0.944, 0.9423, 0.9574]

# %%
V2_cross_val_free_123 = [0.956, 0.9412, 0.9277, 0.9527, 0.939, 0.9522, 0.9544, 0.9505, 0.9442, 0.933, 0.9665, 0.9451, 0.9684, 0.9593, 0.9426, 0.9437, 0.9486, 0.9582, 0.9275, 0.9374]

# %%
V2_cross_val_free_456 = [0.9549, 0.9321, 0.9525, 0.9473, 0.9624, 0.9178, 0.9522, 0.953, 0.9624, 0.9418, 0.9396, 0.95, 0.936, 0.9407, 0.9407, 0.9415, 0.9497, 0.9379, 0.9599, 0.9489]

# %%
V2_cross_val_free_7890 = [0.9508, 0.9448, 0.9214, 0.9536, 0.9179, 0.9552, 0.9508, 0.8868, 0.9404, 0.9206, 0.9632, 0.964, 0.9533, 0.9544, 0.9522, 0.9503, 0.953, 0.9489, 0.9453, 0.9467]

# %%
V2_cross_val_free = V2_cross_val_free_1234 + V2_cross_val_free_5678 + V2_cross_val_free_123 + V2_cross_val_free_456 + V2_cross_val_free_7890

# %%
V2_cross_val_free_max = np.max(V2_cross_val_free)
V2_cross_val_free_max
# Out:
# 0.9684

# %%
V2_cross_val_free_avg = np.mean(V2_cross_val_free)
V2_cross_val_free_avg
# Out:
# 0.9455170000000002

# %% [markdown]
# #### V2 LOO Cross validation, Free Style dataset

# %%
V2_LOO_free_emily = [0.7471, 0.7319, 0.6962, 0.6445, 0.681, 0.7533, 0.758, 0.6985, 0.7362, 0.7416, 0.6461, 0.7463, 0.7339, 0.7024, 0.6857, 0.7304, 0.669, 0.7094, 0.7626, 0.7183]

# %%
V2_LOO_free_grace = [0.3539, 0.3605, 0.3834, 0.3539, 0.3702, 0.3667, 0.3135, 0.3625, 0.4254, 0.3749, 0.3753, 0.3656, 0.3516, 0.3493, 0.3528, 0.3209, 0.3594, 0.3648, 0.3823, 0.378]

# %%
V2_LOO_free_joseph = [0.6818, 0.5917, 0.6507, 0.6092, 0.6931, 0.6659, 0.5975, 0.6472, 0.6686, 0.5878, 0.6305, 0.6177, 0.6197, 0.6775, 0.6535, 0.6002, 0.5719, 0.7028, 0.6181, 0.6908]

# %%
V2_LOO_free_kenny = [0.5579, 0.587, 0.5886, 0.6084, 0.5878, 0.5777, 0.6119, 0.5583, 0.575, 0.6084, 0.5777, 0.6154, 0.622, 0.5664, 0.5326, 0.5692, 0.5051, 0.6158, 0.6154, 0.6049]

# %%
V2_LOO_free_paul = [0.6725, 0.6608, 0.6993, 0.6566, 0.6822, 0.6985, 0.6946, 0.6814, 0.6418, 0.643, 0.6744, 0.6503, 0.6686, 0.648, 0.6605, 0.6702, 0.6737, 0.641, 0.6379, 0.6232]

# %%
V2_LOO_free_peggy = [0.4786, 0.4666, 0.5307, 0.5012, 0.4627, 0.493, 0.4755, 0.5602, 0.4724, 0.4518, 0.4623, 0.4569, 0.5159, 0.5218, 0.4946, 0.5225, 0.4604, 0.5058, 0.4747, 0.5155]

# %%
V2_LOO_free_vincent = [0.8897, 0.8955, 0.8951, 0.8982, 0.8846, 0.8939, 0.8178, 0.873, 0.857, 0.9118, 0.878, 0.8873, 0.897, 0.8885, 0.9068, 0.9025, 0.8978, 0.9172, 0.8559, 0.8702]

# %%
V2_LOO_free_max_avg = (np.max(V2_LOO_free_emily) + np.max(V2_LOO_free_grace) + np.max(V2_LOO_free_joseph) 
                       + np.max(V2_LOO_free_kenny) + np.max(V2_LOO_free_paul) + np.max(V2_LOO_free_peggy)
                       + np.max(V2_LOO_free_vincent))/7
V2_LOO_free_max_avg
# Out:
# 0.6699285714285714

# %%
V2_LOO_free_avg = np.mean(V2_LOO_free_emily+V2_LOO_free_grace+V2_LOO_free_joseph+V2_LOO_free_kenny
                          +V2_LOO_free_paul+V2_LOO_free_peggy+V2_LOO_free_vincent)
V2_LOO_free_avg
# Out:
# 0.6202742857142857

# %% [markdown]
# #### V2 Cross validation, Stipulated dataset

# %%
V2_cross_val_stipulated_1234 = [0.9701, 0.9725, 0.9654, 0.9618, 0.9709, 0.9588, 0.9769, 0.9783, 0.9701, 0.9714, 0.9833, 0.958, 0.9739, 0.9646, 0.9725, 0.975, 0.9816, 0.9613, 0.9662, 0.975]

# %%
V2_cross_val_stipulated_5678 = [0.9758, 0.986, 0.966, 0.9824, 0.9739, 0.9786, 0.9657, 0.9643, 0.9778, 0.9627, 0.975, 0.9613, 0.9789, 0.9797, 0.9739, 0.9789, 0.9676, 0.9717, 0.9742, 0.9778]

# %%
V2_cross_val_stipulated_123 = [0.9736, 0.9676, 0.9731, 0.9596, 0.9585, 0.9783, 0.9805, 0.9791, 0.9698, 0.9775, 0.9657, 0.978, 0.9712, 0.9786, 0.9761, 0.9629, 0.9519, 0.9772, 0.9717, 0.9734]

# %%
V2_cross_val_stipulated_456 = [0.9857, 0.9753, 0.9786, 0.972, 0.9717, 0.9783, 0.9723, 0.9756, 0.9745, 0.9621, 0.9739, 0.9717, 0.975, 0.9789, 0.9805, 0.9684, 0.975, 0.9827, 0.9572, 0.9728]

# %%
V2_cross_val_stipulated_7890 = [0.9701, 0.9745, 0.9791, 0.9813, 0.9838, 0.975, 0.9736, 0.98, 0.9767, 0.9824, 0.9745, 0.9786, 0.9747, 0.9778, 0.9714, 0.9769, 0.9594, 0.9769, 0.9662, 0.9767]

# %%
V2_cross_val_stipulated = V2_cross_val_stipulated_1234 + V2_cross_val_stipulated_5678 + V2_cross_val_stipulated_123 + V2_cross_val_stipulated_456 + V2_cross_val_stipulated_7890

# %%
V2_cross_val_stipulated_max = np.max(V2_cross_val_stipulated)
V2_cross_val_stipulated_max
# Out:
# 0.986

# %%
V2_cross_val_stipulated_avg = np.mean(V2_cross_val_stipulated)
V2_cross_val_stipulated_avg
# Out:
# 0.972959

# %% [markdown]
# #### V2 LOO Cross validation, Stipulated dataset

# %%
V2_LOO_stipulated_emily = [0.8513, 0.8555, 0.9033, 0.8936, 0.8598, 0.8559, 0.9037, 0.8532, 0.8757, 0.8707, 0.8505, 0.8687, 0.8606, 0.8641, 0.8691, 0.9111, 0.8454, 0.8489, 0.8466, 0.8652]

# %%
V2_LOO_stipulated_grace = [0.8595, 0.8144, 0.8525, 0.8602, 0.821, 0.828, 0.828, 0.7931, 0.7826, 0.8637, 0.8311, 0.8071, 0.8067, 0.8226, 0.8509, 0.8307, 0.8692, 0.8731, 0.835, 0.8381]

# %%
V2_LOO_stipulated_joseph = [0.892, 0.8908, 0.9091, 0.8788, 0.8834, 0.9056, 0.9064, 0.9176, 0.8815, 0.8823, 0.8442, 0.8998, 0.9145, 0.8866, 0.8718, 0.8834, 0.9165, 0.8978, 0.8924, 0.8469, 0.8384, 0.8442, 0.8745, 0.8524, 0.8955, 0.9138, 0.8994, 0.9025, 0.8706, 0.8998]

# %%
V2_LOO_stipulated_kenny = [0.7914, 0.7964, 0.7619, 0.8123, 0.7689, 0.8069, 0.7631, 0.803, 0.7813, 0.784, 0.7542, 0.7968, 0.791, 0.722, 0.7926, 0.7914, 0.8104, 0.8038, 0.7867, 0.777, 0.7724, 0.8034, 0.8147, 0.8073, 0.8092, 0.7949, 0.7569, 0.7937, 0.7708, 0.7879]

# %%
V2_LOO_stipulated_paul = [0.8497, 0.8528, 0.8407, 0.8131, 0.7789, 0.8267, 0.7731, 0.803, 0.7863, 0.7991, 0.8186, 0.845, 0.8193, 0.8376, 0.7941, 0.7972, 0.7984, 0.7312, 0.7754, 0.8003, 0.8341, 0.7762, 0.8162, 0.7607, 0.7782, 0.8399, 0.8372, 0.8364, 0.7626, 0.737]

# %%
V2_LOO_stipulated_peggy = [0.7424, 0.7117, 0.7296, 0.683, 0.7036, 0.8007, 0.6981, 0.6908, 0.7828, 0.8007, 0.6904, 0.7106, 0.7789, 0.7552, 0.7075, 0.7498, 0.6702, 0.7257, 0.6484, 0.784]

# %%
V2_LOO_stipulated_vincent = [0.9664, 0.9596, 0.9499, 0.9641, 0.972, 0.9428, 0.9465, 0.961, 0.9708, 0.9697, 0.9437, 0.9343, 0.9258, 0.9277, 0.9126, 0.9068, 0.925, 0.9332, 0.9064, 0.9444, 0.904, 0.9289, 0.951, 0.9332, 0.9343, 0.9336, 0.9017, 0.9561, 0.9017, 0.9087]

# %%
V2_LOO_stipulated_max_avg = (np.max(V2_LOO_stipulated_emily) + np.max(V2_LOO_stipulated_grace) 
                             + np.max(V2_LOO_stipulated_joseph) + np.max(V2_LOO_stipulated_kenny) 
                             + np.max(V2_LOO_stipulated_paul) + np.max(V2_LOO_stipulated_peggy)
                             + np.max(V2_LOO_stipulated_vincent))/7
V2_LOO_stipulated_max_avg
# Out:
# 0.8774285714285713

# %%
V2_LOO_stipulated_avg = np.mean(V2_LOO_stipulated_emily+V2_LOO_stipulated_grace+V2_LOO_stipulated_joseph
                                +V2_LOO_stipulated_kenny+V2_LOO_stipulated_paul+V2_LOO_stipulated_peggy
                                +V2_LOO_stipulated_vincent)
V2_LOO_stipulated_avg
# Out:
# 0.8389900000000002

# %% [markdown]
# ### V3，取絕對值計算Amplitude，並取最大值對應的向量組成Spectrogram

# %% [markdown]
# #### V3 Cross validation, mixed dataset

# %%
V3_cross_val_mixed_1234 = [0.9539, 0.9161, 0.969, 0.9442, 0.955, 0.9566, 0.9496, 0.95, 0.921, 0.9559, 0.9378, 0.9361, 0.9481, 0.9541, 0.9304, 0.9521, 0.9508, 0.9551, 0.9477, 0.9372, 0.9183, 0.9478]

# %%
V3_cross_val_mixed_5678 = [0.946, 0.964, 0.9563, 0.9499, 0.9474, 0.9598, 0.9344, 0.939, 0.9324, 0.9456, 0.9466, 0.9517, 0.9548, 0.936, 0.9495, 0.9471, 0.9496, 0.9394, 0.9643, 0.9496, 0.9528, 0.946]

# %%
V3_cross_val_mixed_123 = [0.9331, 0.9525, 0.958, 0.9383, 0.9556, 0.9396, 0.9324, 0.9193, 0.9422, 0.9503, 0.9594, 0.9338, 0.9477, 0.9497, 0.9305, 0.9223, 0.955, 0.9442, 0.9416, 0.943, 0.974, 0.9294]

# %%
V3_cross_val_mixed_456 = [0.9449, 0.9471, 0.9499, 0.9357, 0.9464, 0.9485, 0.9532, 0.9613, 0.9653, 0.9602, 0.9507, 0.9633, 0.9466, 0.9561, 0.9442, 0.9572, 0.9484, 0.9388, 0.9532, 0.9445, 0.9429, 0.9635]

# %%
V3_cross_val_mixed_7890 = [0.9554, 0.942, 0.9567, 0.9486, 0.9278, 0.9477, 0.9583, 0.9584, 0.957, 0.9404, 0.9455, 0.9375, 0.9533, 0.9459, 0.9485, 0.9241, 0.9519, 0.9485, 0.9578, 0.9452, 0.9566, 0.9609]

# %%
V3_cross_val_mixed = V3_cross_val_mixed_1234 + V3_cross_val_mixed_5678 + V3_cross_val_mixed_123 + V3_cross_val_mixed_456 + V3_cross_val_mixed_7890

# %%
V3_cross_val_mixed_max = np.max(V3_cross_val_mixed)
V3_cross_val_mixed_max
# Out:
# 0.974

# %%
V3_cross_val_mixed_avg = np.mean(V3_cross_val_mixed)
V3_cross_val_mixed_avg
# Out:
# 0.9471890909090908

# %% [markdown]
# #### V3 LOO Cross validation, mixed dataset

# %%
V3_LOO_mixed_emily = [0.8301, 0.8261, 0.8106, 0.7556, 0.7863, 0.776, 0.7814, 0.8093, 0.8269, 0.7954, 0.7874, 0.7478, 0.7932, 0.7901, 0.8135, 0.817, 0.7498, 0.7942, 0.8429, 0.789]

# %%
V3_LOO_mixed_grace = [0.585, 0.6186, 0.62, 0.6003, 0.6055, 0.5833, 0.6231, 0.592, 0.5937, 0.6339, 0.6217, 0.5719, 0.6148, 0.6142, 0.6179, 0.6221, 0.6155, 0.6271, 0.6134, 0.5821, 0.6198, 0.6138]

# %%
V3_LOO_mixed_joseph = [0.8158, 0.8663, 0.8106, 0.8056,  0.8025, 0.8158, 0.7333, 0.8203, 0.7762, 0.8543, 0.8253, 0.7940, 0.8342, 0.8069, 0.7681, 0.8235, 0.7787, 0.8319, 0.7905, 0.8454, 0.8214, 0.8313]

# %%
V3_LOO_mixed_kenny = [0.7581, 0.7218, 0.7214, 0.6816, 0.7071, 0.7353, 0.687, 0.7208, 0.7144, 0.7121, 0.7191, 0.7249, 0.7277, 0.7007, 0.7061, 0.7395, 0.7115, 0.7223, 0.737, 0.7173, 0.6996, 0.7426]

# %%
V3_LOO_mixed_paul = [0.7435, 0.7145, 0.7899, 0.7572, 0.7828, 0.7938, 0.7880, 0.7638, 0.7538, 0.7497, 0.7431, 0.7451, 0.7897, 0.7549, 0.7439, 0.7364, 0.763, 0.7064, 0.7362, 0.7797, 0.7611, 0.7617]

# %%
V3_LOO_mixed_peggy = [0.6504, 0.6631, 0.6817, 0.6065, 0.621, 0.6071, 0.5914, 0.5385, 0.6071, 0.6082, 0.6627, 0.6875, 0.603, 0.6442, 0.6345, 0.6709, 0.597, 0.6446, 0.6519, 0.6535, 0.719, 0.6308, 0.6919]

# %%
V3_LOO_mixed_vincent = [0.9293, 0.9451, 0.9468, 0.9233, 0.931, 0.9412, 0.9536, 0.9078, 0.9482, 0.955, 0.9393, 0.9515, 0.949, 0.9478, 0.9349, 0.9468, 0.9567, 0.9615, 0.9619, 0.9494, 0.9534]

# %%
V3_LOO_mixed_max_avg = (np.max(V3_LOO_mixed_emily) + np.max(V3_LOO_mixed_grace) + np.max(V3_LOO_mixed_joseph) 
                        + np.max(V3_LOO_mixed_kenny) + np.max(V3_LOO_mixed_paul) + np.max(V3_LOO_mixed_peggy)
                        + np.max(V3_LOO_mixed_vincent))/7
V3_LOO_mixed_max_avg
# Out:
# 0.7965571428571429

# %%
V3_LOO_mixed_avg = np.mean(V3_LOO_mixed_emily+V3_LOO_mixed_grace+V3_LOO_mixed_joseph+V3_LOO_mixed_kenny
                           +V3_LOO_mixed_paul+V3_LOO_mixed_peggy+V3_LOO_mixed_vincent)
V3_LOO_mixed_avg
# Out:
# 0.7508572368421053

# %% [markdown]
# #### V3 Cross validation, Free Style dataset

# %%
V3_cross_val_free_1234 = [0.9319, 0.9206, 0.931, 0.9187, 0.9332, 0.9352, 0.9148, 0.9316, 0.9272, 0.9431, 0.9437, 0.942, 0.9055, 0.9124, 0.9091, 0.9409, 0.9335, 0.906, 0.9093, 0.9525]

# %%
V3_cross_val_free_5678 = [0.9124, 0.9049, 0.9522, 0.9401, 0.9195, 0.9228, 0.9385, 0.9036, 0.9118, 0.9475, 0.9448, 0.9398, 0.9489, 0.9475, 0.9266, 0.9412, 0.9374, 0.0393, 0.9371, 0.9464]

# %%
V3_cross_val_free_123 = [0.9338, 0.9453, 0.9423, 0.9275, 0.9258, 0.9354, 0.9387, 0.9173, 0.9308, 0.9451, 0.9275, 0.9209, 0.9448, 0.9462, 0.931, 0.9321, 0.9107, 0.9371, 0.925, 0.9448]

# %%
V3_cross_val_free_456 = [0.9313, 0.9448, 0.9363, 0.928, 0.9404, 0.9236, 0.9451, 0.9332, 0.9294, 0.9453, 0.9277, 0.9203, 0.9335, 0.9236, 0.9453, 0.942, 0.9118, 0.9569, 0.9253, 0.9212]

# %%
V3_cross_val_free_7890 = [0.9522, 0.9225, 0.8953, 0.9003, 0.9376, 0.9291, 0.9236, 0.8775, 0.9003, 0.9055, 0.9387, 0.9385, 0.9316, 0.9475, 0.9228, 0.9363, 0.9363, 0.9489, 0.9453, 0.947]

# %%
V3_cross_val_free = V3_cross_val_free_1234 + V3_cross_val_free_5678 + V3_cross_val_free_123 + V3_cross_val_free_456 + V3_cross_val_free_7890

# %%
V3_cross_val_free_max = np.max(V3_cross_val_free)
V3_cross_val_free_max
# Out:
# 0.9569

# %%
V3_cross_val_free_avg = np.mean(V3_cross_val_free)
V3_cross_val_free_avg
# Out:
# 0.921684

# %% [markdown]
# #### V3 LOO Cross validation, Free Style dataset

# %%
V3_LOO_free_emily = [0.7067, 0.6989, 0.7568, 0.7517, 0.7098, 0.6993, 0.6566, 0.6841, 0.7001, 0.7494, 0.7148, 0.7545, 0.7374, 0.648, 0.6725, 0.6908, 0.7253, 0.7494, 0.7525, 0.6935]

# %%
V3_LOO_free_grace = [0.3823, 0.4091, 0.3446, 0.4149, 0.4538, 0.3283, 0.42, 0.3574, 0.4091, 0.3772, 0.3683, 0.3162, 0.3376, 0.3376, 0.3085, 0.2611, 0.359, 0.3625, 0.3349, 0.3939]

# %%
V3_LOO_free_joseph = [0.603, 0.6111, 0.566, 0.6605, 0.6605, 0.6162, 0.629, 0.6305, 0.5486, 0.6612, 0.6224, 0.6434, 0.6134, 0.5894, 0.6402, 0.6453, 0.5773, 0.62, 0.6752, 0.6138]

# %%
V3_LOO_free_kenny = [0.5925, 0.5633, 0.5734, 0.5583, 0.5186, 0.5528, 0.5703, 0.561, 0.5194, 0.5198, 0.5291, 0.561, 0.5567, 0.5831, 0.5777, 0.608, 0.6111, 0.6197, 0.5369, 0.5761]

# %%
V3_LOO_free_paul = [0.6154, 0.6542, 0.6426, 0.6783, 0.6127, 0.5423, 0.5528, 0.5796, 0.6235, 0.6352, 0.6134, 0.6402, 0.6294, 0.6064, 0.6496, 0.6162, 0.6647, 0.6674, 0.6663, 0.6251]

# %%
V3_LOO_free_peggy = [0.4887, 0.4802, 0.4623, 0.4479, 0.3582, 0.5019, 0.4518, 0.4441, 0.5062, 0.4444, 0.4569, 0.4596, 0.4918, 0.411, 0.5159, 0.5179, 0.4207, 0.4759, 0.4973, 0.5163]

# %%
V3_LOO_free_vincent = [0.8881, 0.8524, 0.9002, 0.9207, 0.866, 0.8873, 0.8609, 0.8955, 0.8862, 0.8726, 0.8772, 0.8625, 0.9033, 0.8745, 0.9025, 0.8757, 0.8834, 0.9052, 0.8978, 0.8559]

# %%
V3_LOO_free_max_avg = (np.max(V3_LOO_free_emily) + np.max(V3_LOO_free_grace) + np.max(V3_LOO_free_joseph) 
                       + np.max(V3_LOO_free_kenny) + np.max(V3_LOO_free_paul) + np.max(V3_LOO_free_peggy)
                       + np.max(V3_LOO_free_vincent))/7
V3_LOO_free_max_avg
# Out:
# 0.6603428571428571

# %%
V3_LOO_free_avg = np.mean(V3_LOO_free_emily+V3_LOO_free_grace+V3_LOO_free_joseph+V3_LOO_free_kenny
                          +V3_LOO_free_paul+V3_LOO_free_peggy+V3_LOO_free_vincent)
V3_LOO_free_avg
# Out:
# 0.6055457142857142

# %% [markdown]
# #### V3 Cross validation, Stipulated dataset

# %%
V3_cross_val_stipulated_1234 = [0.9506, 0.9654, 0.9585, 0.9547, 0.9638, 0.9681, 0.9736, 0.9717, 0.9758, 0.9602, 0.9522, 0.9654, 0.9703, 0.9591, 0.972, 0.975, 0.9665, 0.9618, 0.9728, 0.9541]

# %%
V3_cross_val_stipulated_5678 = [0.9811, 0.9616, 0.9769, 0.9547, 0.9728, 0.9514, 0.9712, 0.9665, 0.9739, 0.9728, 0.9635, 0.9632, 0.9478, 0.9536, 0.9665, 0.9736, 0.9635, 0.9723, 0.9698, 0.9723]

# %%
V3_cross_val_stipulated_123 = [0.9742, 0.9739, 0.9723, 0.9767, 0.9629, 0.9671, 0.9706, 0.9756, 0.9481, 0.9525, 0.9778, 0.9338, 0.9676, 0.9487, 0.9616, 0.9478, 0.9577, 0.9443, 0.9668, 0.9739]

# %%
V3_cross_val_stipulated_456 = [0.9563, 0.9572, 0.9706, 0.9642, 0.9775, 0.9789, 0.9506, 0.9698, 0.9783, 0.9679, 0.9692, 0.9725, 0.9745, 0.9588, 0.964, 0.9624, 0.9712, 0.9767, 0.9522, 0.9714]

# %%
V3_cross_val_stipulated_7890 = [0.9789, 0.9827, 0.9651, 0.9827, 0.9758, 0.9646, 0.9736, 0.9701, 0.958, 0.9734, 0.9717, 0.9767, 0.9725, 0.9616, 0.9714, 0.955, 0.9662, 0.9627, 0.9692, 0.9723]

# %%
V3_cross_val_stipulated = V3_cross_val_stipulated_1234 + V3_cross_val_stipulated_5678 + V3_cross_val_stipulated_123 + V3_cross_val_stipulated_456 + V3_cross_val_stipulated_7890

# %%
V3_cross_val_stipulated_max = np.max(V3_cross_val_stipulated)
V3_cross_val_stipulated_max
# Out:
# 0.9827

# %%
V3_cross_val_stipulated_avg = np.mean(V3_cross_val_stipulated)
V3_cross_val_stipulated_avg
# Out:
# 0.966229

# %% [markdown]
# #### V3 LOO Cross validation, Stipulated dataset

# %%
V3_LOO_stipulated_emily = [0.8489, 0.8404, 0.8781, 0.8287, 0.8637, 0.8474, 0.8489, 0.8528, 0.8606, 0.8625, 0.8392, 0.8287, 0.8311, 0.8256, 0.826, 0.8373, 0.8676, 0.8268, 0.8769, 0.819]

# %%
V3_LOO_stipulated_grace = [0.8055, 0.7993, 0.8377, 0.8156, 0.8129, 0.8269, 0.7993, 0.7849, 0.8234, 0.8148, 0.8226, 0.8102, 0.797, 0.8203, 0.7954, 0.8405, 0.7877, 0.7931, 0.8078, 0.8036]

# %%
V3_LOO_stipulated_joseph = [0.8508, 0.8594, 0.9157, 0.8298, 0.8757, 0.878, 0.871, 0.8792, 0.9009, 0.8485, 0.9056, 0.8998, 0.9103, 0.8834, 0.8675, 0.8563, 0.8858, 0.8811, 0.8811, 0.8415]

# %%
V3_LOO_stipulated_kenny = [0.7848, 0.7371, 0.7681, 0.7596, 0.772, 0.7988, 0.8003, 0.7115, 0.7887, 0.7825, 0.7635, 0.7891, 0.8011, 0.7751, 0.7468, 0.7953, 0.8038, 0.7635, 0.7674, 0.8022]

# %%
V3_LOO_stipulated_paul = [0.7933, 0.7786, 0.7906, 0.7653, 0.7261, 0.8236, 0.8193, 0.8127, 0.8127, 0.7879, 0.7607, 0.8174, 0.7743, 0.8582, 0.7968, 0.8217, 0.8201, 0.7945, 0.7692, 0.8236]

# %%
V3_LOO_stipulated_peggy = [0.7047, 0.6492, 0.7308, 0.6857, 0.7587, 0.7075, 0.7564, 0.7331, 0.772, 0.6733, 0.6204, 0.6981, 0.669, 0.6822, 0.7238, 0.7246, 0.7203, 0.6593, 0.6896, 0.6989]

# %%
V3_LOO_stipulated_vincent = [0.9246, 0.9421, 0.9394, 0.9239, 0.9087, 0.9075, 0.9239, 0.9441, 0.8784, 0.9138, 0.9262, 0.8912, 0.8605, 0.9409, 0.9091, 0.9021, 0.9118, 0.8932, 0.9219, 0.9204]

# %%
V3_LOO_stipulated_max_avg = (np.max(V3_LOO_stipulated_emily) + np.max(V3_LOO_stipulated_grace) 
                             + np.max(V3_LOO_stipulated_joseph) + np.max(V3_LOO_stipulated_kenny) 
                             + np.max(V3_LOO_stipulated_paul) + np.max(V3_LOO_stipulated_peggy)
                             + np.max(V3_LOO_stipulated_vincent))/7
V3_LOO_stipulated_max_avg
# Out:
# 0.8589142857142856

# %%
V3_LOO_stipulated_avg = np.mean(V3_LOO_stipulated_emily+V3_LOO_stipulated_grace+V3_LOO_stipulated_joseph
                                +V3_LOO_stipulated_kenny+V3_LOO_stipulated_paul+V3_LOO_stipulated_peggy
                                +V3_LOO_stipulated_vincent)
V3_LOO_stipulated_avg
# Out:
# 0.8173514285714285

# %%
import pandas as pd

# %%
data_dic = {
    'data version': ['V1', 'V2', 'V3'],
    "cv max (mixed)": [V1_cross_val_mixed_max, V2_cross_val_mixed_max, V3_cross_val_mixed_max], 
    "cv avg (mixed)": [V1_cross_val_mixed_avg, V2_cross_val_mixed_avg, V3_cross_val_mixed_avg],
    "cv max (free)": [V1_cross_val_free_max, V2_cross_val_free_max, V3_cross_val_free_max], 
    "cv avg (free)": [V1_cross_val_free_avg, V2_cross_val_free_avg, V3_cross_val_free_avg],
    "cv max (stipulated)": [V1_cross_val_stipulated_max, V2_cross_val_stipulated_max, V3_cross_val_stipulated_max], 
    "cv avg (stipulated)": [V1_cross_val_stipulated_avg, V2_cross_val_stipulated_avg, V3_cross_val_stipulated_avg],

    "LOO max avg (mixed)": [V1_LOO_mixed_max_avg, V2_LOO_mixed_max_avg, V3_LOO_mixed_max_avg],
    "LOO avg (mixed)": [V1_LOO_mixed_avg, V2_LOO_mixed_avg, V3_LOO_mixed_avg],
    "LOO max avg (free)": [V1_LOO_free_max_avg, V2_LOO_free_max_avg, V3_LOO_free_max_avg],
    "LOO avg (free)": [V1_LOO_free_avg, V2_LOO_free_avg, V3_LOO_free_avg],
    "LOO max avg (stipulated)": [V1_LOO_stipulated_max_avg, V2_LOO_stipulated_max_avg, V3_LOO_stipulated_max_avg],
    "LOO avg (stipulated)": [V1_LOO_stipulated_avg, V2_LOO_stipulated_avg, V3_LOO_stipulated_avg]
    
}
results_df = pd.DataFrame(data_dic)

# %%
results_df
# Out:
#   data version  cv max (mixed)  cv avg (mixed)  cv max (free)  cv avg (free)  \
# 0           V1          0.9561        0.909207         0.9332       0.866464
# 1           V2          0.9728        0.955032         0.9684       0.945517
# 2           V3          0.9740        0.947189         0.9569       0.921684
# 3           V4          0.9576        0.933464         0.9503       0.916750
# 4           V5          0.9517        0.916426         0.9426       0.910646
# 5           V6          0.9610        0.940840         0.9613       0.922641
#
#    cv max (stipulated)  cv avg (stipulated)  LOO max avg (mixed)  \
# 0               0.9580             0.897810             0.777557
# 1               0.9860             0.972959             0.815743
# 2               0.9827             0.966229             0.796557
# 3               0.9816             0.962216             0.791514
# 4               0.9791             0.945646             0.762457
# ...

# %%
results_df.to_csv('comparison.csv')
